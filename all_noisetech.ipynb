# %%
# Add MOSQITO to the Python path
import os
import sys
sys.path.append('..')

# Import numpy
import numpy as np
# Import plot function
import matplotlib.pyplot as plt
# Import spectrum computation tool
from scipy.fft import fft, fftfreq
from scipy.signal import stft
# Import mosqito functions
from mosqito.utils import load

# LOUDNESS_ZWST functions
from mosqito.sq_metrics import loudness_zwst
from mosqito.sq_metrics import loudness_zwst_perseg
from mosqito.sq_metrics import loudness_zwst_freq


# ROUGHNESS_DW functions
from mosqito.sq_metrics import roughness_dw, roughness_dw_freq


# SHARPNESS_DIN functions
from mosqito.sq_metrics import sharpness_din_st
from mosqito.sq_metrics import sharpness_din_perseg
from mosqito.sq_metrics import sharpness_din_from_loudness
from mosqito.sq_metrics import sharpness_din_freq


# Import MOSQITO color sheme [Optional]
from mosqito import COLORS

# To get inline plots (specific to Jupyter notebook)
# %matplotlib notebook

# %%
LOUDNESS_ZWST_STRING = "LOUDNESS_ZWST"
ROUGHNESS_DW_STRING = "ROUGHNESS_DW"
SHARPNESS_DIN_STRING = "SHARPNESS_DIN"

GENERAL_FOLDERS = [LOUDNESS_ZWST_STRING, ROUGHNESS_DW_STRING, SHARPNESS_DIN_STRING]

# %%
def mkdir_folder_wav_name(output_path, wav_name, png_string, folder_string):
    output_path_folder = os.path.join(output_path, f'{folder_string}')
    print(f"The output path for the signal plot is: {output_path_folder}")
    if not os.path.exists(output_path_folder):
        os.makedirs(output_path_folder)
        print(f"The output signal folder was created: {output_path_folder}")
    
    
    #adding the output_path_folder}") + wav_name + '_signal.png' to save the signal plot in the correct folder
    wav_name_path = os.path.join(output_path_folder, wav_name + f'{png_string}')
    print(f"The output path for the signal plot is: {wav_name_path}")

    
    return output_path_folder, wav_name_path

# %%
# Define path to the .wav file
folder_path = r"\\192.168.205.115\aac_server\NoiseTech\3-Medidas\FASE_2"
mision_folders = [f for f in os.listdir(folder_path) if os.path.isdir(os.path.join(folder_path, f))]


for folder in mision_folders:
    mission_path = os.path.join(folder_path, folder)

    #checking if they exit
    if os.path.exists(mission_path):
        # print(f"The folder exists: {mission_path}")


        for general_folder in GENERAL_FOLDERS:

            #5-RESULT FOLDER
            output_path = mission_path.replace("3-Medidas", "5-Resultados")
            if not os.path.exists(output_path):
                os.makedirs(output_path)
                print(f"The output folder was created: {output_path}")
            else:
                print(f"The output folder already exists: {output_path}")
            print()


            # GENERAL FOLDER (LOUDNESS_ZWST, ROUGHNESS_DW, SHARPNESS_DIN)
            general_analysis_folder = os.path.join(output_path, f'{general_folder}')
            print(f"The output path is: {general_analysis_folder}")

            if not os.path.exists(general_analysis_folder):
                os.makedirs(general_analysis_folder)
                print(f"The output folder was created: {general_analysis_folder}")
            else:
                print(f"The output folder already exists: {general_analysis_folder}")
            print()


            wav_files = [f for f in os.listdir(mission_path) if f.endswith('.wav')]
            for wav_file in wav_files:
                file_path = os.path.join(mission_path, wav_file)
                wav_name = os.path.splitext(wav_file)[0]

                # load signal
                sig, fs = load(file_path, wav_calib=2 * 2 **0.5)
                # plot signal
                t = np.linspace(0, (len(sig) - 1) / fs, len(sig))



                if general_folder == LOUDNESS_ZWST_STRING:
                    print()
                    print("ENTERING THE LOUDNESS_ZWST BLOCK")
                    _, loudness_zwst_signal_wav_name = mkdir_folder_wav_name(general_analysis_folder, wav_name, '_signal.png', 'Signal')
                    _, loudness_zwst_wav_name = mkdir_folder_wav_name(general_analysis_folder, wav_name, '_loudness_zwst.png', 'Loudness_Zwicker')
                    _, loudness_zwst_band_rate_wav_name = mkdir_folder_wav_name(general_analysis_folder, wav_name, '_loudness_zwst_band_rate.png', 'Loudness_Zwicker_Band_Rate')
                    _, loudness_zwst_segment_wav_name = mkdir_folder_wav_name(general_analysis_folder, wav_name, '_loudness_zwst_segment.png', 'Loudness_Zwicker_Segment')            
                    _, loudness_zwst_spectrum_wav_name = mkdir_folder_wav_name(general_analysis_folder, wav_name, '_loudness_zwst_spectrum.png', 'Loudness_Zwicker_Spectrum')



                    ###################################
                    ###################################
                    ###################################
                    ## SIGNAL ##
                    ###################################
                    ###################################
                    ###################################
                    plt.figure(1)
                    plt.plot(t, sig, color=COLORS[0])
                    plt.xlabel('Time [s]')
                    plt.ylabel('Acoustic pressure [Pa]')
                    plt.title(f'Signal - {wav_name}')
                    plt.grid()

                    #SAVE
                    plt.savefig(loudness_zwst_signal_wav_name, dpi=300)
                    print(f"Signal plot saved: {loudness_zwst_signal_wav_name}")
                    plt.close()
                    # break




                    # # ###################################
                    # # ###################################
                    # # ###################################
                    # # # COMPUTTING LOUDNESS ZWST
                    # # ###################################
                    # # ###################################
                    # # ###################################
                    N, N_specific, bark_axis = loudness_zwst(sig, fs, field_type="free")
                    print("N_zwst = {:.1f} sone".format(N))
                    print(f"N_zwst = {N:.1f} sone")

                    plt.figure(2)
                    plt.plot(bark_axis, N_specific, color=COLORS[0])
                    plt.xlabel("Critical band rate [Bark]")
                    plt.ylabel("N'_zwst [sone/Bark]")
                    plt.title(f"Loudness Zwicker - N_zwst = {N:.1f} sone - {wav_name}".format(N))
                    plt.grid()

                    # #SAVE
                    plt.savefig(loudness_zwst_wav_name, dpi=300)
                    print(f"Loudness Zwicker plot saved: {loudness_zwst_wav_name}")
                    print()
                    plt.close()
                    



                    # ###################################
                    # ###################################
                    # ###################################
                    # # # SPECIFIC LOUDNESS OVER CRITICAL BAND RATE IS ALSO COMPUTED
                    # ###################################
                    # ###################################
                    # ###################################
                    plt.figure(2)
                    plt.plot(bark_axis, N_specific, color=COLORS[0])
                    plt.xlabel("Critical band rate [Bark]")
                    plt.ylabel("N'_zwst [sone/Bark]")
                    plt.title(f"Loudness Zwicker - N_zwst = {N:.1f} sone - {wav_name}".format(N))
                    plt.grid()

                    # #SAVE
                    plt.savefig(loudness_zwst_band_rate_wav_name, dpi=300)
                    print(f"Loudness Zwicker Band Rate plot saved: {loudness_zwst_band_rate_wav_name}")
                    print()
                    plt.close()



                    # ###################################
                    # ###################################
                    # ###################################
                    # # # SPECIFIC LOUDNESS PER SEGMENT
                    # ###################################
                    # ###################################
                    # ###################################
                    N, N_specific, bark_axis, time_axis = loudness_zwst_perseg(
                        sig, fs, nperseg=8192 * 2, noverlap=4096
                    )
                    plt.figure(3)
                    plt.plot(time_axis, N, color=COLORS[0])
                    plt.xlabel("Time [s]")
                    plt.ylabel("N_zwst [sone]")
                    # plt.ylim((0, 15))
                    plt.title(f"Loudness Zwicker - {wav_name}")
                    plt.grid()

                    # # save
                    plt.savefig(loudness_zwst_segment_wav_name, dpi=300)
                    print(f"Loudness Zwicker Segment plot saved: {loudness_zwst_segment_wav_name}")
                    print()
                    plt.close()


                    # ###################################
                    # ###################################
                    # ###################################
                    # # # FROM SPECTRUM
                    # ###################################
                    # ###################################
                    # ######################################################################
                    # ###################################
                    # ###################################
                    # # # Compute spectrum
                    n = len(sig)
                    spec = np.abs(2 / np.sqrt(2) / n * fft(sig)[0:n//2])
                    freqs = fftfreq(n, 1/fs)[0:n//2]
                    # Compute Loudness
                    N, N_specific, bark_axis = loudness_zwst_freq(spec, freqs)

                    print("N_zwst = {:.1f} sone".format(N) )

                    # Plot the results
                    plt.figure(6)
                    plt.plot(bark_axis, N_specific, color=COLORS[0])
                    plt.xlabel("Critical band rate [Bark]")
                    plt.ylabel("N'_zwst [sone/Bark]")
                    plt.title(f"Loudness Zwicker from spectrum - N_zwst = {N:.1f} sone - {wav_name}".format(N))
                    plt.grid()
                    #save
                    plt.savefig(loudness_zwst_spectrum_wav_name, dpi=300)
                    print(f"Loudness Zwicker Spectrum plot saved: {loudness_zwst_spectrum_wav_name}")
                    print()
                    plt.close()



                if general_folder == ROUGHNESS_DW_STRING:
                    print("ENTERING THE LOUDNESS_ZWST BLOCK")
                    print()
                    _, roughness_dw_wav_name = mkdir_folder_wav_name(general_analysis_folder, wav_name, '_roughness_dw.png', 'Roughness')
                    _, roughness_dw_spectrum_wav_name = mkdir_folder_wav_name(general_analysis_folder, wav_name, '_roughness_dw_spectrum.png', 'Roughness_Spectrum')



                    # ###################################
                    # ###################################
                    # ###################################
                    # # COMPUTTING ROUGHNESS DW
                    # ###################################
                    # ###################################
                    # ###################################
                    r, r_spec, bark, time = roughness_dw(sig, fs, overlap=0)

                    plt.figure(2)
                    plt.plot(time, r, color=COLORS[0])
                    # plt.ylim(0,1.5) # modifying this to plot the whole signal
                    plt.xlabel("Time [s]")
                    plt.ylabel("Roughness [Asper]")
                    plt.title(f'Roughness - {wav_name}')
                    plt.grid()

                    #save
                    plt.savefig(roughness_dw_wav_name, dpi=300)
                    print(f"Roughness plot saved: {roughness_dw_wav_name}")
                    plt.close()



                    ###################################
                    ###################################
                    ###################################
                    # # FROM SPECTRUM
                    ###################################
                    ###################################
                    ######################################################################
                    ###################################
                    ###################################
                    # Compute multiple spectra along time
                    freqs, time, spectrum = stft(sig, fs=fs)

                    # Compute roughness
                    R, R_spec, bark = roughness_dw_freq(spectrum,freqs)

                    # Plot the results
                    plt.figure(6)
                    plt.plot(time, R, color=COLORS[0])
                    # plt.ylim(0,1)
                    plt.xlabel("Time [s]")
                    plt.ylabel("Roughness [Asper]")
                    plt.title(f'Roughness from spectrum - {wav_name}')
                    plt.grid()

                    #save
                    plt.savefig(roughness_dw_spectrum_wav_name, dpi=300)
                    print(f"Roughness Spectrum plot saved: {roughness_dw_spectrum_wav_name}")
                    print()
                    plt.close()




                if general_folder == SHARPNESS_DIN_STRING:
                    _, sharpness_din_wav_name = mkdir_folder_wav_name(general_analysis_folder, wav_name, '_sharpness_din.png', 'Sharpness_Din')
                    _, sharpness_din_spectrum_wav_name = mkdir_folder_wav_name(general_analysis_folder, wav_name, '_sharpness_din_spectrum.png', 'Sharpness_Din_Spectrum')



                    # ###################################
                    # ###################################
                    # ###################################
                    # # COMPUTTING ROUGHNESS DW
                    # ###################################
                    # ###################################
                    # ###################################
                    sharpness = sharpness_din_st(sig, fs, weighting="din")
                    # sharpness = sharpness_din_st(sig, fs, weighting="aures")
                    # sharpness = sharpness_din_st(sig, fs, weighting="fastl")

                    print("Sharpness = {:.1f} acum".format(sharpness) )
                    sharpness_n = "Sharpness = {:.1f} acum".format(sharpness)
                    print(sharpness_n)

                    sharpness, time_axis = sharpness_din_perseg(sig, fs, nperseg=8192 * 2, noverlap=4096, weighting="din")
                    # sharpness, time_axis = sharpness_din_perseg(sig, fs, nperseg=8192 * 2, noverlap=4096, weighting="aures")
                    # sharpness, time_axis = sharpness_din_perseg(sig, fs, nperseg=8192 * 2, noverlap=4096, weighting="fastl")
                    plt.figure(2)
                    plt.plot(time_axis, sharpness, color=COLORS[0])
                    plt.xlabel("Time [s]")
                    plt.ylabel("S_din [acum]")
                    # plt.ylim((0, 3))
                    plt.title(f'Sharpness - {sharpness_n} - {wav_name}')
                    plt.grid()

                    # # save
                    plt.savefig(sharpness_din_wav_name, dpi=300)
                    print(f"Sharpness plot saved: {sharpness_din_wav_name}")
                    print()
                    plt.close()



                    ###################################
                    ###################################
                    ###################################
                    # # FROM SPECTRUM
                    ###################################
                    ###################################
                    ######################################################################
                    ###################################
                    ###################################
                    # Compute spectrum
                    n = len(sig)
                    spec = np.abs(2 / np.sqrt(2) / n * fft(sig)[0:n//2])
                    freqs = fftfreq(n, 1/fs)[0:n//2]
                    # Compute sharpness
                    S = sharpness_din_freq(spec, freqs)
                    print("Sharpness_din = {:.1f} sone".format(S) )

                    # Plot the results
                    plt.figure(6)
                    plt.bar(1, S, color=COLORS[0])
                    # plt.xlim(0,2)
                    # plt.ylim(0,3)
                    plt.xlabel("Sharpness [acum]")
                    plt.title(f'Sharpness from spectrum - {wav_name}')
                    plt.grid()

                    #save
                    plt.savefig(sharpness_din_spectrum_wav_name, dpi=300)
                    print(f"Sharpness Spectrum plot saved: {sharpness_din_spectrum_wav_name}")
                    plt.close()
# Out:
# The output folder already exists: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1
#
# The output path is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST
# The output folder already exists: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST
#
# [Info] Multichannel signal loaded. Keeping only first channel
#
# ENTERING THE LOUDNESS_ZWST BLOCK
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Signal
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Signal\fronton_SanNicolas_signal.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker\fronton_SanNicolas_loudness_zwst.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Band_Rate
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Band_Rate\fronton_SanNicolas_loudness_zwst_band_rate.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Segment
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Segment\fronton_SanNicolas_loudness_zwst_segment.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Spectrum
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Spectrum\fronton_SanNicolas_loudness_zwst_spectrum.png
# Signal plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Signal\fronton_SanNicolas_signal.png
# N_zwst = 28.7 sone
# N_zwst = 28.7 sone
# Loudness Zwicker plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker\fronton_SanNicolas_loudness_zwst.png
#
# Loudness Zwicker Band Rate plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Band_Rate\fronton_SanNicolas_loudness_zwst_band_rate.png
#
# Loudness Zwicker Segment plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Segment\fronton_SanNicolas_loudness_zwst_segment.png
#
# N_zwst = 28.7 sone
# Loudness Zwicker Spectrum plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Spectrum\fronton_SanNicolas_loudness_zwst_spectrum.png
#
# [Info] Multichannel signal loaded. Keeping only first channel
#
# ENTERING THE LOUDNESS_ZWST BLOCK
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Signal
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Signal\niños_SanNicolas_signal.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker\niños_SanNicolas_loudness_zwst.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Band_Rate
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Band_Rate\niños_SanNicolas_loudness_zwst_band_rate.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Segment
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Segment\niños_SanNicolas_loudness_zwst_segment.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Spectrum
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Spectrum\niños_SanNicolas_loudness_zwst_spectrum.png
# Signal plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Signal\niños_SanNicolas_signal.png
# N_zwst = 31.9 sone
# N_zwst = 31.9 sone
# Loudness Zwicker plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker\niños_SanNicolas_loudness_zwst.png
#
# Loudness Zwicker Band Rate plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Band_Rate\niños_SanNicolas_loudness_zwst_band_rate.png
#
# Loudness Zwicker Segment plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Segment\niños_SanNicolas_loudness_zwst_segment.png
#
# N_zwst = 32.0 sone
# Loudness Zwicker Spectrum plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Spectrum\niños_SanNicolas_loudness_zwst_spectrum.png
#
# [Info] Multichannel signal loaded. Keeping only first channel
#
# ENTERING THE LOUDNESS_ZWST BLOCK
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Signal
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Signal\pajaros_SanNicolas_signal.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker\pajaros_SanNicolas_loudness_zwst.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Band_Rate
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Band_Rate\pajaros_SanNicolas_loudness_zwst_band_rate.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Segment
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Segment\pajaros_SanNicolas_loudness_zwst_segment.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Spectrum
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Spectrum\pajaros_SanNicolas_loudness_zwst_spectrum.png
# Signal plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Signal\pajaros_SanNicolas_signal.png
# N_zwst = 4.3 sone
# N_zwst = 4.3 sone
# Loudness Zwicker plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker\pajaros_SanNicolas_loudness_zwst.png
#
# Loudness Zwicker Band Rate plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Band_Rate\pajaros_SanNicolas_loudness_zwst_band_rate.png
#
# Loudness Zwicker Segment plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Segment\pajaros_SanNicolas_loudness_zwst_segment.png
#
# N_zwst = 4.3 sone
# Loudness Zwicker Spectrum plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Spectrum\pajaros_SanNicolas_loudness_zwst_spectrum.png
#
# [Info] Multichannel signal loaded. Keeping only first channel
#
# ENTERING THE LOUDNESS_ZWST BLOCK
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Signal
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Signal\terrazas_fiesta_SanNicolas_signal.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker\terrazas_fiesta_SanNicolas_loudness_zwst.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Band_Rate
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Band_Rate\terrazas_fiesta_SanNicolas_loudness_zwst_band_rate.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Segment
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Segment\terrazas_fiesta_SanNicolas_loudness_zwst_segment.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Spectrum
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Spectrum\terrazas_fiesta_SanNicolas_loudness_zwst_spectrum.png
# Signal plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Signal\terrazas_fiesta_SanNicolas_signal.png
# N_zwst = 22.0 sone
# N_zwst = 22.0 sone
# Loudness Zwicker plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker\terrazas_fiesta_SanNicolas_loudness_zwst.png
#
# Loudness Zwicker Band Rate plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Band_Rate\terrazas_fiesta_SanNicolas_loudness_zwst_band_rate.png
#
# Loudness Zwicker Segment plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Segment\terrazas_fiesta_SanNicolas_loudness_zwst_segment.png
#
# N_zwst = 22.0 sone
# Loudness Zwicker Spectrum plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Spectrum\terrazas_fiesta_SanNicolas_loudness_zwst_spectrum.png
#
# [Info] Multichannel signal loaded. Keeping only first channel
#
# ENTERING THE LOUDNESS_ZWST BLOCK
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Signal
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Signal\terrazas_SanNicolas_signal.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker\terrazas_SanNicolas_loudness_zwst.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Band_Rate
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Band_Rate\terrazas_SanNicolas_loudness_zwst_band_rate.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Segment
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Segment\terrazas_SanNicolas_loudness_zwst_segment.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Spectrum
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Spectrum\terrazas_SanNicolas_loudness_zwst_spectrum.png
# Signal plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Signal\terrazas_SanNicolas_signal.png
# N_zwst = 47.1 sone
# N_zwst = 47.1 sone
# Loudness Zwicker plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker\terrazas_SanNicolas_loudness_zwst.png
#
# Loudness Zwicker Band Rate plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Band_Rate\terrazas_SanNicolas_loudness_zwst_band_rate.png
#
# Loudness Zwicker Segment plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Segment\terrazas_SanNicolas_loudness_zwst_segment.png
#
# N_zwst = 47.1 sone
# Loudness Zwicker Spectrum plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\LOUDNESS_ZWST\Loudness_Zwicker_Spectrum\terrazas_SanNicolas_loudness_zwst_spectrum.png
#
# The output folder already exists: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1
#
# The output path is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\ROUGHNESS_DW
# The output folder already exists: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\ROUGHNESS_DW
#
# [Info] Multichannel signal loaded. Keeping only first channel
# ENTERING THE LOUDNESS_ZWST BLOCK
#
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\ROUGHNESS_DW\Roughness
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\ROUGHNESS_DW\Roughness\fronton_SanNicolas_roughness_dw.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\ROUGHNESS_DW\Roughness_Spectrum
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\ROUGHNESS_DW\Roughness_Spectrum\fronton_SanNicolas_roughness_dw_spectrum.png
# Roughness plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\ROUGHNESS_DW\Roughness\fronton_SanNicolas_roughness_dw.png
# Roughness Spectrum plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\ROUGHNESS_DW\Roughness_Spectrum\fronton_SanNicolas_roughness_dw_spectrum.png
#
# [Info] Multichannel signal loaded. Keeping only first channel
# ENTERING THE LOUDNESS_ZWST BLOCK
#
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\ROUGHNESS_DW\Roughness
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\ROUGHNESS_DW\Roughness\niños_SanNicolas_roughness_dw.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\ROUGHNESS_DW\Roughness_Spectrum
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\ROUGHNESS_DW\Roughness_Spectrum\niños_SanNicolas_roughness_dw_spectrum.png
# Roughness plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\ROUGHNESS_DW\Roughness\niños_SanNicolas_roughness_dw.png
# Roughness Spectrum plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\ROUGHNESS_DW\Roughness_Spectrum\niños_SanNicolas_roughness_dw_spectrum.png
#
# [Info] Multichannel signal loaded. Keeping only first channel
# ENTERING THE LOUDNESS_ZWST BLOCK
#
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\ROUGHNESS_DW\Roughness
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\ROUGHNESS_DW\Roughness\pajaros_SanNicolas_roughness_dw.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\ROUGHNESS_DW\Roughness_Spectrum
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\ROUGHNESS_DW\Roughness_Spectrum\pajaros_SanNicolas_roughness_dw_spectrum.png
# Roughness plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\ROUGHNESS_DW\Roughness\pajaros_SanNicolas_roughness_dw.png
# Roughness Spectrum plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\ROUGHNESS_DW\Roughness_Spectrum\pajaros_SanNicolas_roughness_dw_spectrum.png
#
# [Info] Multichannel signal loaded. Keeping only first channel
# ENTERING THE LOUDNESS_ZWST BLOCK
#
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\ROUGHNESS_DW\Roughness
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\ROUGHNESS_DW\Roughness\terrazas_fiesta_SanNicolas_roughness_dw.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\ROUGHNESS_DW\Roughness_Spectrum
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\ROUGHNESS_DW\Roughness_Spectrum\terrazas_fiesta_SanNicolas_roughness_dw_spectrum.png
# Roughness plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\ROUGHNESS_DW\Roughness\terrazas_fiesta_SanNicolas_roughness_dw.png
# Roughness Spectrum plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\ROUGHNESS_DW\Roughness_Spectrum\terrazas_fiesta_SanNicolas_roughness_dw_spectrum.png
#
# [Info] Multichannel signal loaded. Keeping only first channel
# ENTERING THE LOUDNESS_ZWST BLOCK
#
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\ROUGHNESS_DW\Roughness
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\ROUGHNESS_DW\Roughness\terrazas_SanNicolas_roughness_dw.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\ROUGHNESS_DW\Roughness_Spectrum
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\ROUGHNESS_DW\Roughness_Spectrum\terrazas_SanNicolas_roughness_dw_spectrum.png
# Roughness plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\ROUGHNESS_DW\Roughness\terrazas_SanNicolas_roughness_dw.png
# Roughness Spectrum plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\ROUGHNESS_DW\Roughness_Spectrum\terrazas_SanNicolas_roughness_dw_spectrum.png
#
# The output folder already exists: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1
#
# The output path is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\SHARPNESS_DIN
# The output folder already exists: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\SHARPNESS_DIN
#
# [Info] Multichannel signal loaded. Keeping only first channel
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\SHARPNESS_DIN\Sharpness_Din
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\SHARPNESS_DIN\Sharpness_Din\fronton_SanNicolas_sharpness_din.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\SHARPNESS_DIN\Sharpness_Din_Spectrum
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\SHARPNESS_DIN\Sharpness_Din_Spectrum\fronton_SanNicolas_sharpness_din_spectrum.png
# Sharpness = 1.3 acum
# Sharpness = 1.3 acum
# Sharpness plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\SHARPNESS_DIN\Sharpness_Din\fronton_SanNicolas_sharpness_din.png
#
# Sharpness_din = 1.3 sone
# Sharpness Spectrum plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\SHARPNESS_DIN\Sharpness_Din_Spectrum\fronton_SanNicolas_sharpness_din_spectrum.png
# [Info] Multichannel signal loaded. Keeping only first channel
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\SHARPNESS_DIN\Sharpness_Din
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\SHARPNESS_DIN\Sharpness_Din\niños_SanNicolas_sharpness_din.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\SHARPNESS_DIN\Sharpness_Din_Spectrum
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\SHARPNESS_DIN\Sharpness_Din_Spectrum\niños_SanNicolas_sharpness_din_spectrum.png
# Sharpness = 1.4 acum
# Sharpness = 1.4 acum
# Sharpness plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\SHARPNESS_DIN\Sharpness_Din\niños_SanNicolas_sharpness_din.png
#
# Sharpness_din = 1.4 sone
# Sharpness Spectrum plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\SHARPNESS_DIN\Sharpness_Din_Spectrum\niños_SanNicolas_sharpness_din_spectrum.png
# [Info] Multichannel signal loaded. Keeping only first channel
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\SHARPNESS_DIN\Sharpness_Din
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\SHARPNESS_DIN\Sharpness_Din\pajaros_SanNicolas_sharpness_din.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\SHARPNESS_DIN\Sharpness_Din_Spectrum
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\SHARPNESS_DIN\Sharpness_Din_Spectrum\pajaros_SanNicolas_sharpness_din_spectrum.png
# Sharpness = 2.0 acum
# Sharpness = 2.0 acum
# Sharpness plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\SHARPNESS_DIN\Sharpness_Din\pajaros_SanNicolas_sharpness_din.png
#
# Sharpness_din = 2.0 sone
# Sharpness Spectrum plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\SHARPNESS_DIN\Sharpness_Din_Spectrum\pajaros_SanNicolas_sharpness_din_spectrum.png
# [Info] Multichannel signal loaded. Keeping only first channel
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\SHARPNESS_DIN\Sharpness_Din
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\SHARPNESS_DIN\Sharpness_Din\terrazas_fiesta_SanNicolas_sharpness_din.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\SHARPNESS_DIN\Sharpness_Din_Spectrum
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\SHARPNESS_DIN\Sharpness_Din_Spectrum\terrazas_fiesta_SanNicolas_sharpness_din_spectrum.png
# Sharpness = 1.3 acum
# Sharpness = 1.3 acum
# Sharpness plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\SHARPNESS_DIN\Sharpness_Din\terrazas_fiesta_SanNicolas_sharpness_din.png
#
# Sharpness_din = 1.3 sone
# Sharpness Spectrum plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\SHARPNESS_DIN\Sharpness_Din_Spectrum\terrazas_fiesta_SanNicolas_sharpness_din_spectrum.png
# [Info] Multichannel signal loaded. Keeping only first channel
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\SHARPNESS_DIN\Sharpness_Din
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\SHARPNESS_DIN\Sharpness_Din\terrazas_SanNicolas_sharpness_din.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\SHARPNESS_DIN\Sharpness_Din_Spectrum
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\SHARPNESS_DIN\Sharpness_Din_Spectrum\terrazas_SanNicolas_sharpness_din_spectrum.png
# Sharpness = 1.2 acum
# Sharpness = 1.2 acum
# Sharpness plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\SHARPNESS_DIN\Sharpness_Din\terrazas_SanNicolas_sharpness_din.png
#
# Sharpness_din = 1.2 sone
# Sharpness Spectrum plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_1\SHARPNESS_DIN\Sharpness_Din_Spectrum\terrazas_SanNicolas_sharpness_din_spectrum.png
# The output folder already exists: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7
#
# The output path is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST
# The output folder already exists: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST
#
# [Info] Multichannel signal loaded. Keeping only first channel
#
# ENTERING THE LOUDNESS_ZWST BLOCK
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Signal
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Signal\autovia_bolue_signal.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker\autovia_bolue_loudness_zwst.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Band_Rate
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Band_Rate\autovia_bolue_loudness_zwst_band_rate.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Segment
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Segment\autovia_bolue_loudness_zwst_segment.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Spectrum
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Spectrum\autovia_bolue_loudness_zwst_spectrum.png
# Signal plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Signal\autovia_bolue_signal.png
# N_zwst = 37.7 sone
# N_zwst = 37.7 sone
# Loudness Zwicker plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker\autovia_bolue_loudness_zwst.png
#
# Loudness Zwicker Band Rate plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Band_Rate\autovia_bolue_loudness_zwst_band_rate.png
#
# Loudness Zwicker Segment plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Segment\autovia_bolue_loudness_zwst_segment.png
#
# N_zwst = 37.7 sone
# Loudness Zwicker Spectrum plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Spectrum\autovia_bolue_loudness_zwst_spectrum.png
#
# [Info] Multichannel signal loaded. Keeping only first channel
#
# ENTERING THE LOUDNESS_ZWST BLOCK
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Signal
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Signal\avion_pajaros_bolue_signal.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker\avion_pajaros_bolue_loudness_zwst.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Band_Rate
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Band_Rate\avion_pajaros_bolue_loudness_zwst_band_rate.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Segment
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Segment\avion_pajaros_bolue_loudness_zwst_segment.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Spectrum
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Spectrum\avion_pajaros_bolue_loudness_zwst_spectrum.png
# Signal plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Signal\avion_pajaros_bolue_signal.png
# N_zwst = 27.4 sone
# N_zwst = 27.4 sone
# Loudness Zwicker plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker\avion_pajaros_bolue_loudness_zwst.png
#
# Loudness Zwicker Band Rate plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Band_Rate\avion_pajaros_bolue_loudness_zwst_band_rate.png
#
# Loudness Zwicker Segment plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Segment\avion_pajaros_bolue_loudness_zwst_segment.png
#
# N_zwst = 27.4 sone
# Loudness Zwicker Spectrum plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Spectrum\avion_pajaros_bolue_loudness_zwst_spectrum.png
#
# [Info] Multichannel signal loaded. Keeping only first channel
#
# ENTERING THE LOUDNESS_ZWST BLOCK
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Signal
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Signal\coche_bolue_signal.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker\coche_bolue_loudness_zwst.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Band_Rate
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Band_Rate\coche_bolue_loudness_zwst_band_rate.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Segment
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Segment\coche_bolue_loudness_zwst_segment.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Spectrum
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Spectrum\coche_bolue_loudness_zwst_spectrum.png
# Signal plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Signal\coche_bolue_signal.png
# N_zwst = 30.0 sone
# N_zwst = 30.0 sone
# Loudness Zwicker plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker\coche_bolue_loudness_zwst.png
#
# Loudness Zwicker Band Rate plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Band_Rate\coche_bolue_loudness_zwst_band_rate.png
#
# Loudness Zwicker Segment plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Segment\coche_bolue_loudness_zwst_segment.png
#
# N_zwst = 30.1 sone
# Loudness Zwicker Spectrum plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Spectrum\coche_bolue_loudness_zwst_spectrum.png
#
# [Info] Multichannel signal loaded. Keeping only first channel
#
# ENTERING THE LOUDNESS_ZWST BLOCK
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Signal
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Signal\pajaros_bolue_signal.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker\pajaros_bolue_loudness_zwst.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Band_Rate
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Band_Rate\pajaros_bolue_loudness_zwst_band_rate.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Segment
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Segment\pajaros_bolue_loudness_zwst_segment.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Spectrum
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Spectrum\pajaros_bolue_loudness_zwst_spectrum.png
# Signal plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Signal\pajaros_bolue_signal.png
# N_zwst = 15.7 sone
# N_zwst = 15.7 sone
# Loudness Zwicker plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker\pajaros_bolue_loudness_zwst.png
#
# Loudness Zwicker Band Rate plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Band_Rate\pajaros_bolue_loudness_zwst_band_rate.png
#
# Loudness Zwicker Segment plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Segment\pajaros_bolue_loudness_zwst_segment.png
#
# N_zwst = 15.7 sone
# Loudness Zwicker Spectrum plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Spectrum\pajaros_bolue_loudness_zwst_spectrum.png
#
# [Info] Multichannel signal loaded. Keeping only first channel
#
# ENTERING THE LOUDNESS_ZWST BLOCK
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Signal
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Signal\pajaros_trafico2_bolue_signal.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker\pajaros_trafico2_bolue_loudness_zwst.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Band_Rate
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Band_Rate\pajaros_trafico2_bolue_loudness_zwst_band_rate.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Segment
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Segment\pajaros_trafico2_bolue_loudness_zwst_segment.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Spectrum
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Spectrum\pajaros_trafico2_bolue_loudness_zwst_spectrum.png
# Signal plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Signal\pajaros_trafico2_bolue_signal.png
# N_zwst = 28.7 sone
# N_zwst = 28.7 sone
# Loudness Zwicker plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker\pajaros_trafico2_bolue_loudness_zwst.png
#
# Loudness Zwicker Band Rate plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Band_Rate\pajaros_trafico2_bolue_loudness_zwst_band_rate.png
#
# Loudness Zwicker Segment plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Segment\pajaros_trafico2_bolue_loudness_zwst_segment.png
#
# N_zwst = 28.8 sone
# Loudness Zwicker Spectrum plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Spectrum\pajaros_trafico2_bolue_loudness_zwst_spectrum.png
#
# [Info] Multichannel signal loaded. Keeping only first channel
#
# ENTERING THE LOUDNESS_ZWST BLOCK
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Signal
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Signal\pajaros_trafico_bolue_signal.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker\pajaros_trafico_bolue_loudness_zwst.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Band_Rate
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Band_Rate\pajaros_trafico_bolue_loudness_zwst_band_rate.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Segment
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Segment\pajaros_trafico_bolue_loudness_zwst_segment.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Spectrum
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Spectrum\pajaros_trafico_bolue_loudness_zwst_spectrum.png
# Signal plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Signal\pajaros_trafico_bolue_signal.png
# N_zwst = 18.5 sone
# N_zwst = 18.5 sone
# Loudness Zwicker plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker\pajaros_trafico_bolue_loudness_zwst.png
#
# Loudness Zwicker Band Rate plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Band_Rate\pajaros_trafico_bolue_loudness_zwst_band_rate.png
#
# Loudness Zwicker Segment plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Segment\pajaros_trafico_bolue_loudness_zwst_segment.png
#
# N_zwst = 18.5 sone
# Loudness Zwicker Spectrum plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\LOUDNESS_ZWST\Loudness_Zwicker_Spectrum\pajaros_trafico_bolue_loudness_zwst_spectrum.png
#
# The output folder already exists: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7
#
# The output path is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\ROUGHNESS_DW
# The output folder already exists: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\ROUGHNESS_DW
#
# [Info] Multichannel signal loaded. Keeping only first channel
# ENTERING THE LOUDNESS_ZWST BLOCK
#
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\ROUGHNESS_DW\Roughness
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\ROUGHNESS_DW\Roughness\autovia_bolue_roughness_dw.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\ROUGHNESS_DW\Roughness_Spectrum
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\ROUGHNESS_DW\Roughness_Spectrum\autovia_bolue_roughness_dw_spectrum.png
# Roughness plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\ROUGHNESS_DW\Roughness\autovia_bolue_roughness_dw.png
# Roughness Spectrum plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\ROUGHNESS_DW\Roughness_Spectrum\autovia_bolue_roughness_dw_spectrum.png
#
# [Info] Multichannel signal loaded. Keeping only first channel
# ENTERING THE LOUDNESS_ZWST BLOCK
#
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\ROUGHNESS_DW\Roughness
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\ROUGHNESS_DW\Roughness\pajaros_trafico_bolue_roughness_dw.png
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\ROUGHNESS_DW\Roughness_Spectrum
# The output path for the signal plot is: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\ROUGHNESS_DW\Roughness_Spectrum\pajaros_trafico_bolue_roughness_dw_spectrum.png
# Roughness plot saved: \\192.168.205.115\aac_server\NoiseTech\5-Resultados\FASE_2\Mision_7\ROUGHNESS_DW\Roughness\pajaros_trafico_bolue_roughness_dw.png
